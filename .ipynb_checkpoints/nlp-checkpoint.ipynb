# %%
import codecs
import nltk.data
import pymorphy2
import re
import os
import nltk
from nltk import word_tokenize
from nltk.util import ngrams
from collections import Counter
from itertools import takewhile
morph = pymorphy2.MorphAnalyzer()

# %%
delims = ",.!?/&:;@'*()«»...\n\t\`"
stopwords = open("stopwords.txt", 'r').read().split("\n")
res = []

# Delete delimiters, remove stopwords, make float . stay as _
def process(text):
    title = text.split()[0]
    text = re.sub(r'\[.+?\]\s*', ' ', text)
    text = re.sub(r'«.+?»\s*', ' ', text)
    text = re.sub(r'-', ' ', text)
    text = re.sub(r' — ', ' . ', text)
    text = re.sub(r'([+-]?[0-9]+)\.([0-9]+)',r'\1_\2', text)
    text = re.sub(r'([+-]?[0-9]+),([0-9]+)',r'\1_\2', text)
    stopwords_re = re.compile('|'.join(["\W" + w + "\W" for w in stopwords]))
    text = stopwords_re.sub(".", text.lower())
    text = stopwords_re.sub(".", text)
    lines = [w.strip() for w in re.split("["+"\\".join(delims)+"]", text) if w != ""]
    return title, [' '.join(filter(lambda x: re.match(r'^-?[А-Яа-я]+|-?[A-Za-z]+|-?[1-9]+$', x), 
                                   text.split())) for text in lines]
 
# if there is n-gram keyword with high certanity, delete related n-1-grams
def remove_dups(less, more, num):
    words = [x[0] for x in less]
    todel = []
    for s in more:
        l = s[0].split(' ')
        cnt = 0
        for i in range(len(l) - num + 1):
            if not " ".join(l[i: i + num]).strip() in words:
                break
            cnt = cnt + 1
        if cnt == 2:
            todel += [" ".join(l[i: i + num]) for i in range(len(l) - num + 1)]
    return list(filter(lambda s: s[0] not in todel, less))

# check if difference is only in wordforms
def are_alike(s_a, s_b):
    a = s_a.split(' ')
    b = s_b.split(' ')
    for i in range(len(a)):
        if morph.parse(a[i])[0].normal_form != morph.parse(b[i])[0].normal_form:
            return False
    return True

# remove keywords that differ in wordform only
def remove_wordforms(l):
    new_l = []
    for a in range(len(l)):
        flag = True
        for b in range(a):
            if a != b:
                if are_alike(l[a][0], l[b][0]):
                    flag = False
                    break
        if flag:
            new_l.append(l[a])
    return new_l

def get_confidence(ngram_freq, nless1_freq):
    return (ngram_freq * (ngram_freq * 0.1)) / float(nless1_freq) if ngram_freq > 1 and nless1_freq > 1 else 0

# %%
t = [process(codecs.open("habr/" + f, 'r', "utf_8_sig").read())
        for f in os.listdir("habr")
        if f.endswith(".txt")]

# %%
def get_keywords(data, n1 = 5, n2 = 15, n3 = 10, n4 = 5, n5 = 5, b1 = 0.01):
    total = 0.0
    monograms = []
    bigrams = []
    trigrams = []
    fourgrams = []
    fivegrams = []
    # get ngrams
    for line in data:
        if len(line) == 0:
            continue
        line_len = len(line.split(" "))
        total += line_len

        token = nltk.word_tokenize(line)
        monograms += ngrams(token, 1)
        if line_len < 2:
            continue
        bigrams += ngrams(token, 2)
        if line_len < 3:
            continue
        trigrams += ngrams(token, 3)
        if line_len < 4:
            continue
        fourgrams += ngrams(token, 4)
        if line_len < 5:
            continue
        fivegrams += ngrams(token, 5)

    # get frequencies
    d1 = Counter(monograms)
    d2 = Counter(bigrams)
    d3 = Counter(trigrams)
    d4 = Counter(fourgrams)
    d5 = Counter(fivegrams)

    # get probabilities of occurence of ngram in text, choose keywords based on probability and frequence
    key1 = sorted([(" ".join(x), float(d1[x] / total)) 
            for x in d1], key=lambda tup: tup[1], reverse=True)[:n1]
    # if float(d1[x] / total) > b1]
    key2 = sorted([(" ".join(x), get_confidence(d2[x], d1[(x[0],)])) 
            for x in d2], key=lambda tup: tup[1], reverse=True)[:n2]
    key1 = remove_dups(key1, key2, 1)
    
    key3 = sorted([(" ".join(x), get_confidence(d3[x], d2[(x[0], x[1],)])) 
            for x in d3], key=lambda tup: tup[1], reverse=True)[:n3]
    key2 = remove_dups(key2, key3, 2)

    key4 = sorted([(" ".join(x), get_confidence(d4[x], d3[(x[0], x[1], x[2],)])) 
            for x in d4], key=lambda tup: tup[1], reverse=True)[:n4]
    key3 = remove_dups(key3, key4, 3)    
    
    key5 = sorted([(" ".join(x),get_confidence(d5[x], d4[(x[0], x[1], x[2], x[3],)])) 
            for x in d5], key=lambda tup: tup[1], reverse=True)[:n5]
    key4 = remove_dups(key4, key5, 4)
    #[x[0] for x in ]
    key1 = remove_wordforms(key1)
    key2 = remove_wordforms(key2)
    key3 = remove_wordforms(key3)
    key4 = remove_wordforms(key4)
    key5 = remove_wordforms(key5)
    keywords = key1 + key2 + key3 + key4 + key5
    print(key1)
    print(key2)
    print(key3)

# %%
get_keywords(t[1], n1 = 3, n2 = 20, n3 = 20, n4 = 1, n5 = 1, b1 = 0.1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-388aa0c19f5e> in <module>()
# ----> 1 get_keywords(t[1], n1 = 3, n2 = 20, n3 = 20, n4 = 1, n5 = 1, b1 = 0.1)
#
# <ipython-input-4-68ffcb75ab7b> in get_keywords(data, n1, n2, n3, n4, n5, b1)
#      10         if len(line) == 0:
#      11             continue
# ---> 12         line_len = len(line.split(" "))
#      13         total += line_len
#      14
#
# AttributeError: 'list' object has no attribute 'split'

# %%
with open('out_every_doc.txt','w') as f:
    for (title, data) in text:    
        f.write(title + "\n")
        print(title)
        get_keywords(data)
        for string in keywords:
            if string[1] > 0:
                res.append(string)
            f.write(string + ", ")
        f.write("\n\n")
        print("\n\n")
# Out:
# Node.js
# [('node', 0.0365296803652968), ('js', 0.015220700152207)]
# [('одной причине', 0.2), ('выполнять работу', 0.2), ('событийная модель', 0.2), ('входящих запросов', 0.2), ('ввода вывода', 0.2), ('event loop', 0.2), ('перед node', 0.13333333333333333), ('давайте начнём', 0.13333333333333333), ('веб сервер', 0.1285714285714286), ('http сервер', 0.09000000000000001), ('n 2', 0.06666666666666667), ('веб приложения', 0.05714285714285715), ('философию unix', 0), ('этом страшного', 0), ('ное число', 0)]
# [('свой собственный http', 0), ('ное число фибоначчи', 0), ('любое очередное нытьё', 0), ('поставить настоящий веб', 0), ('радиация приносит пользу', 0), ('учитывая оригинальную маркетинговую', 0), ('любой адекватный программист', 0), ('сующих nginx перед', 0), ('предыдущем ноутбуке результат', 0), ('таки решишься подойти', 0)]
#
#
#
# История
# [('афера', 0.010221465076660987), ('деньги', 0.008517887563884156), ('карты', 0.008517887563884156)]
# [('тверской области', 0.6000000000000001), ('сельского хозяйства', 0.2), ('русского лото', 0.13333333333333333), ('оформление стенда', 0.13333333333333333), ('карты твери', 0.08), ('молодому человеку', 0), ('увидевшего фотошоп', 0), ('напечатать фальшивые', 0), ('делать бизнес', 0), ('одной рекламы', 0), ('тщательно отбирал', 0), ('делая откровенную', 0), ('дорого одеваться', 0)]
# [('справочник тверских банков', 0.2), ('туризма тверской области', 0), ('обещал конкретную зарплату', 0), ('маячить новые кандидаты', 0), ('продавец билетов русского', 0), ('проводят гибкую откатную', 0), ('различимыми голубыми цветочками', 0), ('американский стартаперов кристиана', 0), ('предложено замечательное решение', 0), ('удалось брать деньги', 0)]
#
#
#
# Нифига
# []
# [('units cylinders', 0.4), ('512 bytes', 0.4), ('fd linux', 0.4), ('raid autodetect', 0.32), ('t contain', 0.30000000000000004), ('a valid', 0.30000000000000004)]
# [('linux raid autodetect', 0.4), ('fd linux raid', 0.4), ('units cylinders of', 0.4), ('valid partition table', 0.30000000000000004)]
#
#
#
# Как
# [('компании', 0.009370816599732263), ('собеседования', 0.009370816599732263), ('hr', 0.009370816599732263), ('три', 0.006693440428380187), ('резюме', 0.006693440428380187)]
# [('техническим специалистом', 0.2), ('тестовое задание', 0.2), ('одной компании', 0.13333333333333333), ('большинство наших', 0.1), ('три месяца', 0.08), ('hr менеджеры', 0.05714285714285715), ('карту сокровищ', 0), ('заниматься знающий', 0), ('руководитель it', 0), ('моей реализации', 0), ('два дня', 0), ('такой психологический', 0), ('код инжектором', 0), ('настольным футболом', 0)]
# [('обдумана сумма оклада', 0), ('техническую часть собеседования', 0), ('разработчикам мобильных приложений', 0), ('нанять опытного программиста', 0), ('компаниях второго эшелона', 0), ('hr менеджеров читает', 0), ('обладают достаточными знаниями', 0), ('небольшом рекламном агентстве', 0), ('немного выше средней', 0), ('целыми днями бегаю', 0)]
#
#
#
# Не
# [('программиста', 0.008802816901408451), ('неделя', 0.00528169014084507), ("''", 0.00528169014084507), ('нужно', 0.00528169014084507)]
# [('шаблонное поведение', 0.2), ('поведенческих антипаттернах', 0.2), ('несознательные личности', 0), ('набираем программиста', 0), ('решения проблемы', 0), ('ночам выходить', 0), ('ближайшего окружения', 0), ('естественной реакцией', 0), ('сделайте скриншот', 0), ('трубку сразу', 0), ('оставил любителей', 0), ('хотел превращаться', 0), ('моей точки', 0), ('требуется передышка', 0), ('хотите выпустить', 0)]
# [('программиста нужно неустанно', 0), ('топика формой подачи', 0), ('любимых выражений программистов', 0), ('лучшая часть суток', 0), ('проблем перед выходными', 0), ('профессии редко выступают', 0), ('содержание топика формой', 0), ('нудное содержание топика', 0), ('преследовал другую цель', 0), ('сильно помог автор', 0)]
#
#
#
# Как
# [('mail', 0.024), ('деньги', 0.008), ('момент', 0.006857142857142857)]
# [('ru group', 0.324), ('искать деньги', 0.2), ('накануне ipo', 0.2), ('денис крючков', 0.2), ('верди исраелян', 0.2), ('дмитрий гришин', 0.2), ('55 долларов', 0.13333333333333333), ('большой бизнес', 0.13333333333333333), ('ipo mail', 0), ('инвестором интернет', 0), ('сильно перегнули', 0), ('плоха идея', 0), ('принять решение', 0), ('отказался создавать', 0), ('подобной истории', 0)]
# [('выкупить 55 процентов', 0), ('отдавали компанию полностью', 0), ('млн уникальных пользователей', 0), ('dst феликс шпильман', 0), ('инвестором интернет проектов', 0), ('самых эпохальных событий', 0), ('предложил мильнеру выкупить', 0), ('ним обязующие документы', 0), ('запах вкусной лапши', 0), ('стоит взять интервью', 0)]
#
#
#
# Банкомат.
# [('атм', 0.030211480362537766), ('банкомат', 0.01812688821752266), ('код', 0.0075528700906344415), ('поэтому', 0.0075528700906344415)]
# [('платежными картами', 0.2), ('pin код', 0.13333333333333333), ('три раза', 0.13333333333333333), ('одного атм', 0.13333333333333333), ('тысяч долларов', 0.13333333333333333), ('кассета выбраковки', 0.13333333333333333), ('сейф банкомата', 0), ('новых современных', 0), ('дальнем пустом', 0), ('помалу привыкли', 0), ('имеет pin', 0), ('важный момент', 0), ('15 градусов', 0), ('угодно купюр', 0), ('нагревательных элементов', 0)]
# [('вводить криптографические ключи', 0), ('атм начинал капризничать', 0), ('два человека получают', 0), ('раза неправильно ввел', 0), ('три порванных купюры', 0), ('посему собственных фотографий', 0), ('мы насобирали изрядную', 0), ('снять большую сумму', 0), ('выбраковки торчали деньги', 0), ('атм начнёт выдавать', 0)]
#
#
#
# Почему
# [('ооо', 0.022199798183652877), ('ип', 0.018163471241170535), ('пункт', 0.008072653884964682), ('юр', 0.007063572149344097), ('числе', 0.006054490413723511)]
# [('малый бизнес', 0.2), ('генеральный директор', 0.2), ('входными параметрами', 0.2), ('прочих равных', 0.2), ('могут возникнуть', 0.13333333333333333), ('выплата дивидендов', 0.13333333333333333), ('вести бухучет', 0.13333333333333333), ('фрилансер предоставляет', 0.1), ('регистрации ооо', 0.08), ('чем налогов', 0), ('должен получать', 0)]
# [('стоит начать работать', 0.2), ('начальном этапе ип', 0.1), ('формы деятельности очевиден', 0), ('закрыть ип символическая', 0), ('превышать четырёх пятимесячную', 0), ('обязательным визитом налоговиков', 0), ('выбор формы деятельности', 0), ('спокойно переводить деньги', 0), ('охотой займутся непонятной', 0), ('начать работать главная', 0)]
#
#
#
# Поможем
# [('среднее', 0.013888888888888888), ('клиента', 0.012345679012345678), ('сесть', 0.010802469135802469), ('подумать', 0.009259259259259259), ('операции', 0.007716049382716049)]
# [('замерить показатели', 0.2), ('удобно должно', 0.13333333333333333), ('выполнения операций', 0.1), ('среднее количество', 0.044444444444444446), ('какую информацию', 0), ('алгоритм действий', 0), ('попытаться внедрить', 0), ('немножко верим', 0), ('понятной цифрой', 0), ('найти решения', 0), ('отделения уволен', 0), ('отделении образовалась', 0), ('стоит заполнить', 0)]
# [('каждом шаге операции', 0.2), ('разных окнах выполняют', 0), ('банке должны работать', 0), ('среднее количество неудачных', 0), ('частном случае нужны', 0), ('среднее количество обращений', 0), ('стремление сменить вывеску', 0), ('неочевидные сценарии действий', 0), ('попытаться внедрить решения', 0), ('улучшением пользовательского опыта', 0)]
#
#
#
# ак
# [('positive', 0.01697792869269949), ('z', 0.015280135823429542), ('n', 0.015280135823429542)]
# [('положительных оценок', 1.1266666666666667), ('positive negative', 0.49000000000000005), ('from widgets', 0.30000000000000004), ('увидевших сообщение', 0.30000000000000004), ('order by', 0.30000000000000004), ('допускают подобную', 0.2), ('средняя оценка', 0.2), ('the american', 0.2), ('urban dictionary', 0.2), ('итоге положительных', 0.2), ('неправильное решение', 0.2), ('первого объекта', 0.2), ('average rating', 0.2)]
# [('общее число оценок', 0.2), ('допускают подобную ошибку', 0.2), ('объекта положительных оценок', 0.2), ('число положительных оценок', 0.2), ('между долей положительных', 0)]
#
#
#
# Принцип
# [('2', 0.01511879049676026), ('1', 0.01511879049676026), ('png', 0.009719222462203024), ('3', 0.008639308855291577), ('числа', 0.00755939524838013)]
# [('простые числа', 0.4), ('элементе html', 0.2), ('можете представить', 0.2), ('могучий легион', 0.2), ('натуральной случайности', 0.2), ('ruffle unit', 0.2), ('53 a', 0.13333333333333333), ('29 a', 0.1), ('37 a', 0.1), ('собираюсь выбрать', 0.1), ('2 изображения', 0.0642857142857143), ('облегчить стыковку', 0), ('хватает роста', 0), ('теоретической размером', 0)]
# [('практически бесконечный фон', 0), ('начинает немножко разбиваться', 0), ('трёхлетнего пика численности', 0), ('графика олицетворяет собой', 0), ('matters to web', 0), ('периодические цикады одновременно', 0), ('представляет собой уникальное', 0), ('натуральной случайности средствами', 0), ('второго уровня используем', 0), ('иллюзия натуральной случайности', 0)]
#
#
#
# Как
# [('часть', 0.008422234699606962), ('поэтому', 0.0050533408197641775), ('семен', 0.004491858506457047), ('данных', 0.0039303761931499155), ('николай', 0.003368893879842785)]
# [('дисковую группу', 0.30000000000000004), ('сухим молоком', 0.2), ('менеджер проекта', 0.2), ('запуск комплекса', 0.2), ('ленточная библиотека', 0.2), ('запчасть сразу', 0.13333333333333333), ('9 утра', 0.13333333333333333), ('мою заявку', 0.13333333333333333), ('голове моей', 0.08), ('карьеры оказался', 0), ('дело подергиваясь', 0), ('голове иссякли', 0)]
# [('начала рабочего дня', 0.2), ('проводил рабочее совещание', 0), ('правильное человеческое счастье', 0), ('ответственные финансовые системы', 0), ('забыл разговорные навыки', 0), ('взошла большая оранжевая', 0), ('конфигурация дисковой группы', 0), ('вокруг лежали провода', 0), ('удивился своему голосу', 0), ('робот подумал секунду', 0)]
#
#
#
# Почему
# [('версии', 0.013605442176870748), ('ie10', 0.012244897959183673), ('ie11', 0.009523809523809525)]
# [('умеет работать', 0.4), ('юзер агенту', 0.32), ('developer preview', 0.30000000000000004), ('движок gecko', 0.2), ('en us', 0.2), ('предыдущих версий', 0.2), ('тщательно портирован', 0), ('две версии', 0), ('режиме показывать', 0), ('мажорных релизов', 0), ('windows должен', 0)]
# [('windows 7 or', 0), ('же людей обработка', 0), ('специальный флаг navigator', 0), ('хром давно перешли', 0), ('версии internet explorer', 0), ('разных версий ie', 0), ('разработка веб сайтов', 0), ('помимо разных версий', 0)]
#
#
#
# Вы
# [('баг', 0.008253094910591471), ('легко', 0.0068775790921595595), ('поэтому', 0.0068775790921595595), ('вообще', 0.0068775790921595595), ('проблемы', 0.005502063273727648)]
# [('точно писал', 0.13333333333333333), ('алгоритм обхода', 0), ('известный баг', 0), ('белку garbage', 0), ('светлая мысль', 0), ('помощью подстановки', 0), ('одном процессе', 0), ('ограниченной памятью', 0), ('рептильной платформой', 0), ('основном релизе', 0), ('без видимого', 0), ('слонёнок деплоится', 0), ('проблемы энергопотребления', 0), ('вообще достойно', 0), ('гениальные низкоуровневые', 0)]
# [('отключили центральный сектор', 0), ('инъекцию произвольного яйца', 0), ('разработчик придумал заставить', 0), ('качестве учебного примера', 0), ('нормальный алгоритм обхода', 0), ('разработка веб сайтов', 0), ('долгих высокоуровневых процессов', 0), ('позволяет провести animal', 0), ('чистой виртуальной машине', 0), ('очереди опрашивает прерывания', 0)]
#
#
#
# Как
# [('памяти', 0.023445463812436288), ('managed', 0.009174311926605505), ('случае', 0.0061162079510703364)]
# [('vertex buffer', 0.6000000000000001), ('потребление памяти', 0.4166666666666667), ('оперативной памяти', 0.30000000000000004), ('alt tab', 0.2), ('far cry', 0.2), ('концу игры', 0.2), ('самых разных', 0.2), ('большую часть', 0.2), ('стало понятно', 0.13333333333333333), ('вершинных буферов', 0.13333333333333333), ('civilization 4', 0.13333333333333333), ('default пулом', 0.08), ('managed пул', 0.044444444444444446), ('представление данных', 0)]
# [('данных vertex buffer', 0), ('начинают лезть нехорошие', 0), ('drawindexedprimitive вместо моего', 0), ('поэтому неоправданное поедание', 0), ('оперативки постепенно съехала', 0), ('случае избытка видеопамяти', 0), ('обычных c шных', 0), ('же годы вышел', 0), ('поедание памяти sc2', 0), ('затрудняет подготовить заранее', 0)]
#
#
#
# Когда
# [('говорил', 0.05442176870748299), ('продолжали', 0.04081632653061224), ('нужно', 0.02040816326530612)]
# [('тысячи долларов', 0.2), ('технические статьи', 0.2), ('люки круглые', 0.2), ('заманивать айтишников', 0), ('вкладывать деньги', 0), ('нужно задавать', 0), ('учебный процесс', 0), ('продолжали спрашивать', 0), ('дарили футболки', 0), ('куча 23', 0), ('средненьких теннисистов', 0), ('читать хабр', 0), ('продолжали раздавать', 0)]
# [('абстрактный класс отличается', 0.30000000000000004), ('любые совпадения случайны', 0), ('продолжали раздавать деньги', 0), ('любое мероприятие начинается', 0), ('нужно задавать головоломки', 0), ('много средненьких теннисистов', 0), ('писать технические статьи', 0), ('устанавливать скрам доски', 0), ('нельзя заманивать айтишников', 0), ('продолжали устраивать agile', 0)]
#
#
#
# Особенности
# [('нужно', 0.006809338521400778), ('компании', 0.005836575875486381), ('приводит', 0.005836575875486381), ('наших', 0.005836575875486381), ('команде', 0.0048638132295719845)]
# [('high context', 0.2), ('задавать вопросы', 0.2), ('часть нашей', 0.13333333333333333), ('активного троллинга', 0), ('сразу начинали', 0), ('друг другу', 0), ('15 минут', 0), ('is friday', 0), ('чистого любопытства', 0), ('западный коллега', 0), ('медали две', 0), ('скраме решения', 0), ('зрения особенностей', 0)]
# [('давать обратную связь', 0.2), ('реальное поведение людей', 0), ('ним спокойно разговаривали', 0), ('недетская паранойя приводит', 0), ('итоге уровень энергии', 0), ('коллега американец уточняет', 0), ('показалось смутно знакомым', 0), ('you know that', 0), ('тренинге справился минуты', 0), ('организовывали первый открытый', 0)]
#
#
#
# О
# [('входа', 0.017793594306049824), ('сообщение', 0.010676156583629894), ('изменения', 0.010676156583629894), ('сервера', 0.010676156583629894), ('протокола', 0.0071174377224199285)]
# [('контакт листа', 0.2), ('основе полученной', 0), ('проблема заключается', 0), ('используемая версия', 0), ('1 сообщение', 0), ('серверного контакт', 0), ('заметить интересный', 0), ('отправляемых пакетов', 0), ('обмена сообщениями', 0), ('переменным успехом', 0), ('начальном значении', 0), ('клиентом фишках', 0), ('высказали предположение', 0)]
# [('некий дополнительный ключ', 0), ('можете сравнить скриншоты', 0), ('клиентом фишках протокола', 0), ('просьбе shoohurt рассказываю', 0), ('сеть icq распределенная', 0), ('официальные версии программ', 0), ('раз аол пошел', 0), ('аол пошел путем', 0), ('команде разработчиков miranda', 0), ('повторилась ситуация 8', 0)]
#
#
#
# Free-lance.ru
# [('сайте', 0.02262443438914027), ('фриланс', 0.01809954751131222), ('сообщения', 0.01809954751131222)]
# [('личные сообщения', 0.2), ('free lance', 0.2), ('явно положил', 0), ('ru сошёл', 0), ('сайте нельзя', 0), ('объявления войны…', 0), ('признанные империи', 0), ('пользователем фриланса', 0), ('работу бюрократизацию', 0), ('новых желающих', 0), ('любой опрос', 0), ('огромный баннер', 0), ('фриланс решил', 0), ('приватные беседы', 0), ('пользоваться сайтом', 0)]
# [('читает личные сообщения', 0), ('решаюсь ставить галочку', 0), ('аккаунт pro регулярно', 0), ('признанные империи зла', 0), ('явно положил свой', 0), ('фриланс официально заявляет', 0), ('поставили перед фактом', 0), ('проверку обстоятельств работы', 0)]
#
#
#
# Интернет
# [('евро', 0.016766467065868262), ('день', 0.01437125748502994), ('ограничений', 0.008383233532934131), ('решил', 0.008383233532934131), ('магазин', 0.00718562874251497)]
# [('личных ограничений', 0.6000000000000001), ('пять адаптеров', 0.30000000000000004), ('выхода ipad', 0.30000000000000004), ('15 евро', 0.2), ('последний месяц', 0.2), ('уровень конверсии', 0.2), ('ключевым словам', 0.2), ('пол часа', 0.2), ('open source', 0.2), ('крупные партии', 0.2), ('средний оборот', 0.13333333333333333), ('интернет магазин', 0.13333333333333333), ('небольшой it', 0)]
# [('2 3 часа', 0.2), ('стали потихоньку подтягиваться', 0), ('исключение подтверждающее правило', 0), ('открыть интернет магазин', 0), ('день приходить человек', 0), ('месяц создал монополию', 0), ('тип товара радовала', 0), ('в день писали', 0), ('ценообразованию подойти максимально', 0), ('продукт отвечающий моему', 0)]
#
#
#
# Самый
# [('”', 0.013245033112582781), ('людей', 0.008278145695364239), ('богатым', 0.008278145695364239), ('делал', 0.006622516556291391), ('примеры', 0.006622516556291391)]
# [('контр примеры', 0.2), ('ограниченному ресурсу', 0.2), ('станете богатым', 0.13333333333333333), ('делал старался', 0.1), ('тривиальные вещи', 0), ('человечество знало', 0), ('сегодняшних действий', 0), ('ценные бумаги', 0), ('продолжать заниматься', 0), ('истории успешных', 0), ('отчетливо демонстрируют', 0), ('конкретные обстоятельства', 0), ('целью разбогатеть', 0), ('kind of', 0), ('докторской степени', 0)]
# [('упоминание банальщины вроде', 0), ('some kind of', 0), ('повышенное количество статей', 0), ('прошлогодняя выигрышная комбинация', 0), ('положительного финансового эффекта', 0), ('необходимости вывода оттуда', 0), ('жизнь постоянно демонстрирует', 0), ('ортогонально вашей деятельности', 0), ('кризиса великой депрессии', 0), ('ваших сегодняшних действий', 0)]
#
#
#
# Безопасен
# [('ключ', 0.029906542056074768), ('telegram', 0.028037383177570093), ('nonce', 0.011214953271028037), ('t', 0.009345794392523364)]
# [('открытый ключ', 0.4), ('сервера telegram', 0.22500000000000003), ('установил клиент', 0.2), ('закрытый ключ', 0.2), ('случайную последовательность', 0.2), ('digital fortress', 0.2), ('визуализацию ключа', 0.2), ('mod dh_prime', 0.2), ('диффи хелмана', 0.2), ('номер телефона', 0.13333333333333333)]
# [('открытое простое число', 0.2), ('вычисляет секретный ключ', 0.2), ('видом открытого ключа', 0.2), ('ввел номер телефона', 0), ('читать api протокола', 0), ('пользователи мессенджера требуют', 0), ('момент первого запуска', 0), ('генерирует собственные ключи', 0), ('телефон приходит смс', 0), ('открытого ключа боба', 0)]
#
#
#
# Психологическая
# [('программистов', 0.013333333333333334), ('код', 0.012), ('например', 0.009333333333333334)]
# [('реальной жизни', 0.30000000000000004), ('психологической деформации', 0.2), ('работы программиста', 0.2), ('данный момент', 0.15000000000000002), ('должен работать', 0.1), ('качественная работа', 0), ('могут казаться', 0), ('в большинстве', 0), ('частично восприниматься', 0), ('старается сделать', 0), ('момент размышлять', 0)]
# [('причинно следственных связей', 0.4), ('уровень социального взаимодействия', 0.2), ('спорный момент ввиду', 0), ('социального взаимодействия имеет', 0), ('накладывает свой отпечаток', 0), ('взаимодействия имеют указанную', 0), ('формализованной постановке задач', 0), ('например недавняя статья', 0), ('большинство имеет семьи', 0), ('цели здесь преследуются', 0)]
#
#
#
# 300
# [('webkit', 0.02237136465324385), ('стандартов', 0.011185682326621925), ('chromium', 0.011185682326621925)]
# [('новых стандартов', 0.2), ('internet explorer', 0.2), ('миллионов пользователей', 0.2), ('новой версии', 0.2), ('поддержку стандартов', 0.2), ('продолжат работать', 0.2), ('проект webkit', 0.2), ('пользователей opera', 0.08), ('получит нужный', 0), ('стоит помнить', 0), ('начинали разработку', 0), ('особенно мобильными', 0), ('необходимые браузерные', 0), ('способ определения', 0)]
# [('отправляя патчи прямо', 0), ('имеет такую поддержку', 0), ('вторую проекту webkit', 0), ('получили огромную популярность', 0), ('продолжим нашу работу', 0), ('правильный способ определения', 0), ('будущих версиях opera', 0), ('17 летний опыт', 0), ('являются жизненно важной', 0), ('анонсом нового достижения', 0)]
#
#
#
# [UPDATED
# [('приложение', 0.015927189988623434), ('ребенок', 0.01478953356086462), ('апи', 0.013651877133105802), ('1', 0.010238907849829351), ('доступ', 0.010238907849829351)]
# [('мое приложение', 0.4), ('новое апи', 0.30000000000000004), ('тебя убивают', 0.2), ('пытались найти', 0.2), ('интернет помнит', 0.2), ('платное приложение', 0.2), ('использовать апи', 0.2), ('ребенка откладывается', 0.1), ('ребенок получает', 0.03076923076923077), ('исходники приложения', 0), ('безумно повезло', 0)]
# [('могут учиться хорошо', 0.2), ('ребенок открывает дневник', 0.2), ('глазах рисовалась насмешка', 0), ('открывался uс browser', 0), ('платное приложение заработали', 0), ('просить саппорт сделать', 0), ('сложнее изменить среднее', 0), ('ребенок мог получить', 0), ('главном экране сразу', 0), ('открывает дневник ребенка', 0)]
#
#
#
# Как
# [('com', 0.03485254691689008), ('%', 0.032171581769437), ('github', 0.032171581769437), ('баг', 0.021447721179624665), ('гитхаб', 0.01876675603217158)]
# [('валидации redirect_uri', 0.2), ('рельс сессии', 0), ('прочитаю куку', 0), ('встроена защита', 0), ('слитый code', 0), ('подписанная кука', 0), ('отослать site', 0), ('можем открыть', 0), ('первый баг', 0), ('моем сервере', 0), ('возьму оттуда', 0), ('загружают host', 0), ('рекомендуется хранить', 0), ('разработка веб', 0), ('прокси гитхаба', 0)]
# [('camo прокси гитхаба', 0), ('hacked github again', 0), ('код оставался валидным', 0), ('адрес гитхаб автоматически', 0), ('гитхаб запустил баунти', 0), ('браузер загружает gist', 0), ('перезаписать предыдущий путь', 0), ('вызовы совершенно незаметно', 0), ('токен необходимо дать', 0), ('смогу совершать api', 0)]
#
#
#
# Были
# [('svn', 0.0267515923566879), ('ru', 0.015286624203821656), ('p', 0.011464968152866241), ('уязвимость', 0.007643312101910828), ('яндекса', 0.007643312101910828)]
# [('исходные коды', 0.30000000000000004), ('text base', 0.2), ('версия скрипта', 0.2), ('postgresql уважают', 0.2), ('удалось получить', 0.2), ('веб сервера', 0.13333333333333333), ('средствами svn', 0.1), ('средствами вебсервера', 0.1), ('svn base', 0.01904761904761905), ('следует рассказать', 0), ('процент исходных', 0), ('структуру корня', 0), ('дальнейшими планами', 0), ('получая сайт', 0)]
# [('отличный си программист', 0), ('корни веб морды', 0), ('управлением apache чтение', 0), ('заблокировать потенциально опасные', 0), ('wikimedia postgresql уважают', 0), ('сервера nginx ответил', 0), ('большинству проектов последние', 0), ('элементарной возможностью утечки', 0), ('находится директори text', 0), ('настройке сразу заблокировать', 0)]
#
#
#
# Что
# [('либо', 0.006993006993006993), ('достаточно', 0.006293706293706294), ('момент', 0.005594405594405594), ('рамы', 0.0048951048951048955), ('долго', 0.0048951048951048955)]
# [('lotus seven', 0.2), ('силовой установке', 0.2), ('поворотные кулаки', 0.2), ('московский друг', 0.2), ('какого либо', 0.2), ('отдельная песня', 0.2), ('сварочный аппарат', 0.2), ('картинки кликабельны', 0.2), ('пространственной рамы', 0.2), ('процесс сборки', 0.13333333333333333), ('интересные темы', 0), ('очень весело', 0), ('растягивать проект', 0)]
# [('достаточно быстро нашли', 0.08), ('попытки прокатиться обнаружили', 0), ('проскакивание звеньев цепи', 0), ('из интересующихся получится', 0), ('популярна среди it', 0), ('внезапная идея создать', 0), ('lotus seven колина', 0), ('момент разнятся достаточно', 0), ('электрической цепи нашего', 0), ('мирно гуляющих мамочек', 0)]
#
#
#
# Как
# [('банка', 0.020202020202020204), ('xxx', 0.013468013468013467), ('атака', 0.013468013468013467), ('web', 0.013468013468013467), ('ip', 0.013468013468013467)]
# [('ip адресов', 0.1), ('действия дали', 0), ('приманку переименовал', 0), ('росли логи', 0), ('эффективность свелась', 0), ('географию атакующих', 0), ('возвращаемую страницу', 0), ('logparser быстро', 0), ('украинских хостеров', 0), ('сергей иванович', 0), ('анализ показал', 0), ('ловил хакера', 0), ('публичных платежных', 0), ('it департаменте', 0)]
# [('количества ip адресов', 0), ('уродами нужно бороться', 0), ('атакой вполне справлялись', 0), ('достаточно ip адрес', 0), ('какого либо сегмента', 0), ('началась ddos атака', 0), ('вашего сервера идет', 0), ('координация ddos атаки', 0)]

# %%
with open ('out_global', 'w') as f:
    for string in res:
        f.write(string + ", ")
